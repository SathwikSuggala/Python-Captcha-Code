# %%
from tkinter import*
from tkinter import messagebox
root = Tk()
root.geometry('350x350')
l=[]
label=Label(root,text="Select the Black Image",font=('Courier 14'))
def sahil():
    x=1
    l.append(x)
def sathwik():
    x=1324
    l.append(x)
def sathwik1():
    x=22213
    l.append(x)
def sathwik2():
    x=657893
    l.append(x)
def sathwik3():
    x=91824
    l.append(x)
def sai():
    x=sum(l)
    if(x==773254):
        print("captcha is correct")
        messagebox.showinfo("captcha","Captcha correct")
        l.clear()
    else:
        print('invalid captcha')
        messagebox.showinfo("captcha","Captcha incorrect")
        l.clear()
def refresh():
    rooot = Toplevel()
    rooot.geometry('350x350')
    l=[]
    label=Label(rooot,text="Select the Black Image",font=('Courier 14'))
    def sahil():
        x=1
        l.append(x)
    def sathwik():
        x=1324
        l.append(x)
    def sathwik1():
        x=22213
        l.append(x)
    def sathwik2():
        x=657893
        l.append(x)
    def sathwik3():
        x=91824
        l.append(x)
    def sai():
        x=sum(l)
        if(x==773254):
            print("captcha is correct")
            messagebox.showinfo("captcha","Captcha correct")
            l.clear()
        else:
            print('invalid captcha')
            messagebox.showinfo("captcha","Captcha incorrect")
            l.clear()
    def reset1():
        roooot = Toplevel()
        roooot.geometry('350x350')
        l=[]
        label=Label(roooot,text="Select the Black Image",font=('Courier 14'))
        def sahil():
            x=1
            l.append(x)
        def sathwik():
            x=1324
            l.append(x)
        def sathwik1():
            x=22213
            l.append(x)
        def sathwik2():
            x=657893
            l.append(x)
        def sathwik3():
            x=91824
            l.append(x)
        def sai():
            x=sum(l)
            if(x==773254):
                print("captcha is correct")
                messagebox.showinfo("captcha","Captcha correct")
                l.clear()
            else:
                print('invalid captcha')
                messagebox.showinfo("captcha","Captcha incorrect")
                l.clear()
        img = PhotoImage(file = 'download.png')
        imge= PhotoImage(file = 'car.png')
        Button(roooot, image = imge, width = 50, height = 50,command=sathwik).place(x=100,y=100)#1

        Button(roooot, image = img, width = 50, height = 50, command=sahil).place(x=150,y=100)#2
        Button(roooot, image = img, width = 50, height = 50,command=sahil).place(x=200,y=100)#3
        Button(roooot, image = imge, width = 50, height = 50,command=sathwik2).place(x=100,y=150)#4
        Button(roooot, image = img, width = 50, height = 50,command=sahil).place(x=150,y=150)#5
        Button(roooot, image = imge, width = 50, height = 50,command=sathwik1).place(x=200,y=150)#6
        Button(roooot, image = imge, width = 50, height = 50,command=sathwik3).place(x=100,y=200)#7
        Button(roooot, image = img, width = 50, height = 50,command=sahil).place(x=150,y=200)#8
        Button(roooot, image = img, width = 50, height = 50,command=sahil).place(x=200,y=200)#9
        Button(roooot, text = "submit",command=sai).place(x=150,y=270)
        Button(roooot, text = "reset",command=sai).place(x=220,y=70)
        label.place(x=50,y=30)
        roooot.mainloop()
        
        
        
        
        
        
    img = PhotoImage(file = 'download.png')
    imge= PhotoImage(file = 'car.png')
    Button(rooot, image = imge, width = 50, height = 50,command=sathwik).place(x=100,y=100)#1
    
    Button(rooot, image = img, width = 50, height = 50, command=sahil).place(x=150,y=100)#2
    Button(rooot, image = imge, width = 50, height = 50,command=sathwik1).place(x=200,y=100)#3
    Button(rooot, image = imge, width = 50, height = 50,command=sathwik2).place(x=100,y=150)#4
    Button(rooot, image = img, width = 50, height = 50,command=sahil).place(x=150,y=150)#5
    Button(rooot, image = img, width = 50, height = 50,command=sahil).place(x=200,y=150)#6
    Button(rooot, image = img, width = 50, height = 50,command=sahil).place(x=100,y=200)#7
    Button(rooot, image = img, width = 50, height = 50,command=sahil).place(x=150,y=200)#8
    Button(rooot, image = imge, width = 50, height = 50,command=sathwik3).place(x=200,y=200)#9
    Button(rooot, text = "submit",command=sai).place(x=150,y=270)
    Button(rooot, text = "reset",command=reset1).place(x=220,y=70)
    label.place(x=50,y=30)
    rooot.mainloop()
    
    
    
    
img = PhotoImage(file = 'download.png')
Button(root, image = img, width = 50, height = 50, command=sahil).place(x=100,y=100)#1
imge= PhotoImage(file = 'car.png')
Button(root, image = imge, width = 50, height = 50,command=sathwik).place(x=150,y=100)#2
Button(root, image = imge, width = 50, height = 50,command=sathwik1).place(x=200,y=100)#3
Button(root, image = img, width = 50, height = 50,command=sahil).place(x=100,y=150)#4
Button(root, image = imge, width = 50, height = 50,command=sathwik2).place(x=150,y=150)#5
Button(root, image = img, width = 50, height = 50,command=sahil).place(x=200,y=150)#6
Button(root, image = img, width = 50, height = 50,command=sahil).place(x=100,y=200)#7
Button(root, image = imge, width = 50, height = 50,command=sathwik3).place(x=150,y=200)#8
Button(root, image = img, width = 50, height = 50,command=sahil).place(x=200,y=200)#9
Button(root, text = "submit",command=sai).place(x=150,y=270)
Button(root, text = "reset",command=refresh).place(x=220,y=70)
label.place(x=50,y=30)
    
root.mainloop()
# Out:
# invalid captcha

# %%
from tkinter import*
from tkinter import messagebox
root = Tk()
root.geometry('350x350')
l=[]
label=Label(root,text="Select the Black Image",font=('Courier 14'))
def sahil():
    x=1
    l.append(x)
def sathwik():
    x=1324
    l.append(x)
def sathwik1():
    x=22213
    l.append(x)
def sathwik2():
    x=657893
    l.append(x)
def sathwik3():
    x=91824
    l.append(x)
def sai():
    x=sum(l)
    if(x==773254):
        print("captcha is correct")
        messagebox.showinfo("captcha","Captcha correct")
        l.clear()
    else:
        print('invalid captcha')
        messagebox.showinfo("captcha","Captcha incorrect")
        l.clear()
def refresh():
    rooot = Toplevel()
    rooot.geometry('350x350')
    l=[]
    label=Label(rooot,text="Select the Black Image",font=('Courier 14'))
    def sahil():
        x=1
        l.append(x)
    def sathwik():
        x=1324
        l.append(x)
    def sathwik1():
        x=22213
        l.append(x)
    def sathwik2():
        x=657893
        l.append(x)
    def sathwik3():
        x=91824
        l.append(x)
    def sai():
        x=sum(l)
        if(x==773254):
            print("captcha is correct")
            messagebox.showinfo("captcha","Captcha correct")
            l.clear()
        else:
            print('invalid captcha')
            messagebox.showinfo("captcha","Captcha incorrect")
            l.clear()
    def reset1():
        roooot = Toplevel()
        roooot.geometry('350x350')
        l=[]
        label=Label(roooot,text="Select the Black Image",font=('Courier 14'))
        def sahil():
            x=1
            l.append(x)
        def sathwik():
            x=1324
            l.append(x)
        def sathwik1():
            x=22213
            l.append(x)
        def sathwik2():
            x=657893
            l.append(x)
        def sathwik3():
            x=91824
            l.append(x)
        def sai():
            x=sum(l)
            if(x==773254):
                print("captcha is correct")
                messagebox.showinfo("captcha","Captcha correct")
                l.clear()
            else:
                print('invalid captcha')
                messagebox.showinfo("captcha","Captcha incorrect")
                l.clear()
        def reset2():
            rooooot = Toplevel()
            rooooot.geometry('350x350')
            l=[]
            label=Label(roooot,text="Select the Black Image",font=('Courier 14'))
            def sahil():
                x=1
                l.append(x)
            def sathwik():
                x=1324
                l.append(x)
            def sathwik1():
                x=22213
                l.append(x)
            def sathwik2():
                x=657893
                l.append(x)
            def sathwik3():
                x=91824
                l.append(x)
            def sai():
                x=sum(l)
                if(x==773254):
                    print("captcha is correct")
                    messagebox.showinfo("captcha","Captcha correct")
                    l.clear()
                else:
                    print('invalid captcha')
                    messagebox.showinfo("captcha","Captcha incorrect")
                    l.clear()
            img = PhotoImage(file = 'download.png')
            imge= PhotoImage(file = 'car.png')
            Button(rooooot, image = imge, width = 50, height = 50,command=sathwik).place(x=100,y=100)#1

            Button(rooooot, image = img, width = 50, height = 50, command=sahil).place(x=150,y=100)#2
            Button(rooooot, image = img, width = 50, height = 50,command=sahil).place(x=200,y=100)#3
            Button(rooooot, image = imge, width = 50, height = 50,command=sathwik2).place(x=100,y=150)#4
            Button(rooooot, image = img, width = 50, height = 50,command=sahil).place(x=150,y=150)#5
            Button(rooooot, image = imge, width = 50, height = 50,command=sathwik1).place(x=200,y=150)#6
            Button(rooooot, image = imge, width = 50, height = 50,command=sathwik3).place(x=100,y=200)#7
            Button(rooooot, image = img, width = 50, height = 50,command=sahil).place(x=150,y=200)#8
            Button(rooooot, image = img, width = 50, height = 50,command=sahil).place(x=200,y=200)#9
            Button(rooooot, text = "submit",command=sai).place(x=150,y=270)
            Button(rooooot, text = "reset",command=refresh).place(x=220,y=70)
            label.place(x=50,y=30)
            rooooot.mainloop()
            
            
        img = PhotoImage(file = 'download.png')
        imge= PhotoImage(file = 'car.png')
        Button(roooot, image = imge, width = 50, height = 50,command=sathwik).place(x=100,y=100)#1

        Button(roooot, image = img, width = 50, height = 50, command=sahil).place(x=150,y=100)#2
        Button(roooot, image = img, width = 50, height = 50,command=sahil).place(x=200,y=100)#3
        Button(roooot, image = imge, width = 50, height = 50,command=sathwik2).place(x=100,y=150)#4
        Button(roooot, image = img, width = 50, height = 50,command=sahil).place(x=150,y=150)#5
        Button(roooot, image = imge, width = 50, height = 50,command=sathwik1).place(x=200,y=150)#6
        Button(roooot, image = imge, width = 50, height = 50,command=sathwik3).place(x=100,y=200)#7
        Button(roooot, image = img, width = 50, height = 50,command=sahil).place(x=150,y=200)#8
        Button(roooot, image = img, width = 50, height = 50,command=sahil).place(x=200,y=200)#9
        Button(roooot, text = "submit",command=sai).place(x=150,y=270)
        Button(roooot, text = "reset",command=reset2).place(x=220,y=70)
        label.place(x=50,y=30)
        roooot.mainloop()
        
        
        
        
        
        
    img = PhotoImage(file = 'download.png')
    imge= PhotoImage(file = 'car.png')
    Button(rooot, image = imge, width = 50, height = 50,command=sathwik).place(x=100,y=100)#1
    
    Button(rooot, image = img, width = 50, height = 50, command=sahil).place(x=150,y=100)#2
    Button(rooot, image = imge, width = 50, height = 50,command=sathwik1).place(x=200,y=100)#3
    Button(rooot, image = imge, width = 50, height = 50,command=sathwik2).place(x=100,y=150)#4
    Button(rooot, image = img, width = 50, height = 50,command=sahil).place(x=150,y=150)#5
    Button(rooot, image = img, width = 50, height = 50,command=sahil).place(x=200,y=150)#6
    Button(rooot, image = img, width = 50, height = 50,command=sahil).place(x=100,y=200)#7
    Button(rooot, image = img, width = 50, height = 50,command=sahil).place(x=150,y=200)#8
    Button(rooot, image = imge, width = 50, height = 50,command=sathwik3).place(x=200,y=200)#9
    Button(rooot, text = "submit",command=sai).place(x=150,y=270)
    Button(rooot, text = "reset",command=reset1).place(x=220,y=70)
    label.place(x=50,y=30)
    rooot.mainloop()
    
    
    
    
img = PhotoImage(file = 'download.png')
Button(root, image = img, width = 50, height = 50, command=sahil).place(x=100,y=100)#1
imge= PhotoImage(file = 'car.png')
Button(root, image = imge, width = 50, height = 50,command=sathwik).place(x=150,y=100)#2
Button(root, image = imge, width = 50, height = 50,command=sathwik1).place(x=200,y=100)#3
Button(root, image = img, width = 50, height = 50,command=sahil).place(x=100,y=150)#4
Button(root, image = imge, width = 50, height = 50,command=sathwik2).place(x=150,y=150)#5
Button(root, image = img, width = 50, height = 50,command=sahil).place(x=200,y=150)#6
Button(root, image = img, width = 50, height = 50,command=sahil).place(x=100,y=200)#7
Button(root, image = imge, width = 50, height = 50,command=sathwik3).place(x=150,y=200)#8
Button(root, image = img, width = 50, height = 50,command=sahil).place(x=200,y=200)#9
Button(root, text = "submit",command=sai).place(x=150,y=270)
Button(root, text = "reset",command=refresh).place(x=220,y=70)
label.place(x=50,y=30)
    
root.mainloop()

# %%
from tkinter import*
from tkinter import messagebox
root = Tk()
root.geometry('350x350')
l=[]
label=Label(root,text="Select the Black Image",font=('Courier 14'))
def click():
    x=1
    l.append(x)
def on():
    x=1324
    l.append(x)
def sel1():
    x=22213
    l.append(x)
def sel2():
    x=657893
    l.append(x)
def sel3():
    x=91824
    l.append(x)
def check():
    x=sum(l)
    if(x==773254):
        print("captcha is correct")
        messagebox.showinfo("captcha","Captcha correct")
        l.clear()
    else:
        print('invalid captcha')
        messagebox.showinfo("captcha","Captcha incorrect")
        l.clear()
def refresh():
    root.destroy()
    rooot = Toplevel()
    rooot.geometry('350x350')
    l=[]
    label=Label(rooot,text="Select the Black Image",font=('Courier 14'))
    def click():
        x=1
        l.append(x)
    def on():
        x=1324
        l.append(x)
    def sel1():
        x=22213
        l.append(x)
    def sel2():
        x=657893
        l.append(x)
    def sel3():
        x=91824
        l.append(x)
    def check():
        x=sum(l)
        if(x==773254):
            print("captcha is correct")
            messagebox.showinfo("captcha","Captcha correct")
            l.clear()
        else:
            print('invalid captcha')
            messagebox.showinfo("captcha","Captcha incorrect")
            l.clear()
    def reset1():
        rooot.destroy()
        roooot = Toplevel()
        roooot.geometry('350x350')
        l=[]
        label=Label(roooot,text="Select the Black Image",font=('Courier 14'))
        def click():
            x=1
            l.append(x)
        def on():
            x=1324
            l.append(x)
        def sel1():
            x=22213
            l.append(x)
        def sel2():
            x=657893
            l.append(x)
        def sel3():
            x=91824
            l.append(x)
        def check():
            x=sum(l)
            if(x==773254):
                print("captcha is correct")
                messagebox.showinfo("captcha","Captcha correct")
                l.clear()
            else:
                print('invalid captcha')
                messagebox.showinfo("captcha","Captcha incorrect")
                l.clear()
        def reset2():
            roooot.destroy()
            rooooot = Toplevel()
            rooooot.geometry('350x350')
            l=[]
            label=Label(roooot,text="Select the Black Image",font=('Courier 14'))
            def click():
                x=1
                l.append(x)
            def on():
                x=1324
                l.append(x)
            def sel1():
                x=22213
                l.append(x)
            def sel2():
                x=657893
                l.append(x)
            def sel3():
                x=91824
                l.append(x)
            def check():
                x=sum(l)
                if(x==773254):
                    print("captcha is correct")
                    messagebox.showinfo("captcha","Captcha correct")
                    l.clear()
                else:
                    print('invalid captcha')
                    messagebox.showinfo("captcha","Captcha incorrect")
                    l.clear()
            img = PhotoImage(file = 'download.png')
            imge= PhotoImage(file = 'car.png')
            Button(rooooot, image = imge, width = 50, height = 50,command=on).place(x=100,y=100)#1

            Button(rooooot, image = img, width = 50, height = 50, command=click).place(x=150,y=100)#2
            Button(rooooot, image = img, width = 50, height = 50,command=click).place(x=200,y=100)#3
            Button(rooooot, image = imge, width = 50, height = 50,command=sel2).place(x=100,y=150)#4
            Button(rooooot, image = img, width = 50, height = 50,command=click).place(x=150,y=150)#5
            Button(rooooot, image = imge, width = 50, height = 50,command=sel1).place(x=200,y=150)#6
            Button(rooooot, image = imge, width = 50, height = 50,command=sel3).place(x=100,y=200)#7
            Button(rooooot, image = img, width = 50, height = 50,command=click).place(x=150,y=200)#8
            Button(rooooot, image = img, width = 50, height = 50,command=click).place(x=200,y=200)#9
            Button(rooooot, text = "submit",command=check).place(x=150,y=270)
            Button(rooooot, text = "reset",command=refresh).place(x=220,y=70)
            label.place(x=50,y=30)
            rooooot.mainloop()
            
            
        img = PhotoImage(file = 'download.png')
        imge= PhotoImage(file = 'car.png')
        Button(roooot, image = imge, width = 50, height = 50,command=on).place(x=100,y=100)#1

        Button(roooot, image = img, width = 50, height = 50, command=click).place(x=150,y=100)#2
        Button(roooot, image = img, width = 50, height = 50,command=click).place(x=200,y=100)#3
        Button(roooot, image = imge, width = 50, height = 50,command=sel2).place(x=100,y=150)#4
        Button(roooot, image = img, width = 50, height = 50,command=click).place(x=150,y=150)#5
        Button(roooot, image = imge, width = 50, height = 50,command=sel1).place(x=200,y=150)#6
        Button(roooot, image = imge, width = 50, height = 50,command=sel3).place(x=100,y=200)#7
        Button(roooot, image = img, width = 50, height = 50,command=click).place(x=150,y=200)#8
        Button(roooot, image = img, width = 50, height = 50,command=click).place(x=200,y=200)#9
        Button(roooot, text = "submit",command=check).place(x=150,y=270)
        Button(roooot, text = "reset",command=reset2).place(x=220,y=70)
        label.place(x=50,y=30)
        roooot.mainloop()
        
        
        
        
        
        
    img = PhotoImage(file = 'download.png')
    imge= PhotoImage(file = 'car.png')
    Button(rooot, image = imge, width = 50, height = 50,command=on).place(x=100,y=100)#1
    
    Button(rooot, image = img, width = 50, height = 50, command=click).place(x=150,y=100)#2
    Button(rooot, image = imge, width = 50, height = 50,command=sel1).place(x=200,y=100)#3
    Button(rooot, image = imge, width = 50, height = 50,command=sel2).place(x=100,y=150)#4
    Button(rooot, image = img, width = 50, height = 50,command=click).place(x=150,y=150)#5
    Button(rooot, image = img, width = 50, height = 50,command=click).place(x=200,y=150)#6
    Button(rooot, image = img, width = 50, height = 50,command=click).place(x=100,y=200)#7
    Button(rooot, image = img, width = 50, height = 50,command=click).place(x=150,y=200)#8
    Button(rooot, image = imge, width = 50, height = 50,command=sel3).place(x=200,y=200)#9
    Button(rooot, text = "submit",command=check).place(x=150,y=270)
    Button(rooot, text = "reset",command=reset1).place(x=220,y=70)
    label.place(x=50,y=30)
    rooot.mainloop()
    
    
    
    
img = PhotoImage(file = 'download.png')
Button(root, image = img, width = 50, height = 50, command=on).place(x=100,y=100)#1
imge= PhotoImage(file = 'car.png')
Button(root, image = imge, width = 50, height = 50,command=click).place(x=150,y=100)#2
Button(root, image = imge, width = 50, height = 50,command=sel1).place(x=200,y=100)#3
Button(root, image = img, width = 50, height = 50,command=click).place(x=100,y=150)#4
Button(root, image = imge, width = 50, height = 50,command=sel2).place(x=150,y=150)#5
Button(root, image = img, width = 50, height = 50,command=click).place(x=200,y=150)#6
Button(root, image = img, width = 50, height = 50,command=click).place(x=100,y=200)#7
Button(root, image = imge, width = 50, height = 50,command=sel3).place(x=150,y=200)#8
Button(root, image = img, width = 50, height = 50,command=click).place(x=200,y=200)#9
Button(root, text = "submit",command=check).place(x=150,y=270)
Button(root, text = "reset",command=refresh).place(x=220,y=70)
label.place(x=50,y=30)
    
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sathwik\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\sathwik\AppData\Local\Temp\ipykernel_14896\1005334466.py", line 99, in reset2
#     label=Label(roooot,text="Select the Black Image",font=('Courier 14'))
#   File "C:\Users\sathwik\anaconda3\lib\tkinter\__init__.py", line 3148, in __init__
#     Widget.__init__(self, master, 'label', cnf, kw)
#   File "C:\Users\sathwik\anaconda3\lib\tkinter\__init__.py", line 2572, in __init__
#     self.tk.call(
# _tkinter.TclError: bad window path name ".!toplevel2"

# %%
from tkinter import*
from tkinter import messagebox
captcha = Tk()
captcha.geometry('350x350')
l=[]
label=Label(captcha,text="Select the Black Image",font=('Courier 14'))
def click():
    x=1
    l.append(x)
def on():
    x=1324
    l.append(x)
def sel1():
    x=22213
    l.append(x)
def sel2():
    x=657893
    l.append(x)
def sel3():
    x=91824
    l.append(x)
def check():
    x=sum(l)
    if(x==773254):
        print("captcha is correct")
        messagebox.showinfo("captcha","Captcha correct")
        l.clear()
    else:
        print('invalid captcha')
        messagebox.showinfo("captcha","Captcha incorrect")
        l.clear()
    captcha.destroy()
img = PhotoImage(file = 'download.png')
Button(captcha, image = img, width = 50, height = 50, command=click).place(x=100,y=100)#1
imge= PhotoImage(file = 'car.png')
Button(captcha, image = imge, width = 50, height = 50,command=on).place(x=150,y=100)#2
Button(captcha, image = imge, width = 50, height = 50,command=sel1).place(x=200,y=100)#3
Button(captcha, image = img, width = 50, height = 50,command=click).place(x=100,y=150)#4
Button(captcha, image = imge, width = 50, height = 50,command=sel2).place(x=150,y=150)#5
Button(captcha, image = img, width = 50, height = 50,command=click).place(x=200,y=150)#6
Button(captcha, image = img, width = 50, height = 50,command=click).place(x=100,y=200)#7
Button(captcha, image = imge, width = 50, height = 50,command=sel3).place(x=150,y=200)#8
Button(captcha, image = img, width = 50, height = 50,command=click).place(x=200,y=200)#9
Button(captcha, text = "submit",command=check).place(x=150,y=270)
label.place(x=50,y=30)
    
captcha.mainloop()

# %%
from tkinter import*
from tkinter import messagebox
from PIL import Image, ImageTk
captcha = Tk()
captcha.geometry('400x525')
captcha.resizable(False, False)
captcha.title('Image Captcha')
l=[]
def click():
    x=int(1)
    l.append(x)
def on():
    x=int(1324)
    l.append(x)
def sel1():
    x=int(222130)
    l.append(x)
def sel2():
    x=int(657893)
    l.append(x)
def sel3():
    x=int(91824)
    l.append(x)
def check():
    x=sum(l)
    if(x==973171):
        print("captcha is correct")
        messagebox.showinfo("captcha","Captcha correct")
        l.clear()
    else:
        print('invalid captcha')
        messagebox.showinfo("captcha","Captcha incorrect")
        l.clear()
    captcha.destroy()

fr1 = Frame(captcha,height =50,width=120)
fr1.pack(fill = 'x')
fr1.pack_propagate(False)

fr2 = Frame(captcha,height = 450)
fr2.pack(fill = 'x')
fr2.pack_propagate(False)

lg=PhotoImage(file='car.png')
c=Image.open('car.png')
d=c.resize((50, 50))
lg=ImageTk.PhotoImage(d)

label=Label(fr1,bg = 'white',image=lg ,height = 95, width = 50)
label.grid(row=0,column=1)

x= Label(fr1,bg = 'white',height=5,width=35,text = 'Select all the Images with Cars',font=(' Calibri 12'))
x.grid(row=0,column=2)


a=Image.open('Recaptchlogo.png')
b=a.resize((50, 50))
re=ImageTk.PhotoImage(b)

captcha.wm_iconbitmap('icon.ico')

m=Label(fr1,bg = 'white',image=re,height = 95, width = 50)
m.grid(row=0,column=3)

image=Image.open('car4.png')
g=image.resize((125, 120))
img1=ImageTk.PhotoImage(g)

e=Image.open('car1.png')
f=e.resize((125, 120))
img2=ImageTk.PhotoImage(f)

h=Image.open('car2.png')
i=h.resize((125, 120))
img3=ImageTk.PhotoImage(i)

j=Image.open('car3.png')
k=j.resize((120, 120))
img4=ImageTk.PhotoImage(k)

n=Image.open('bike3.png')
o=n.resize((125, 120))
img5=ImageTk.PhotoImage(o)

p=Image.open('cy1.png')
q=p.resize((125, 120))
img6=ImageTk.PhotoImage(q)

r=Image.open('tc1.png')
s=r.resize((125, 120))
img7=ImageTk.PhotoImage(s)

u=Image.open('lr1.png')
v=u.resize((125, 120))
img8=ImageTk.PhotoImage(v)

w=Image.open('bike2.png')
x=w.resize((125, 120))
img9=ImageTk.PhotoImage(x)

img = PhotoImage(file = 'download.png')
Button(fr2, image = img5, width = 125, height = 120, command=click).grid(row=1,column=1)#1
Button(fr2, image = img1, width = 125, height = 120,command=on).grid(row=1,column=2)#2
Button(fr2, image = img6, width = 125, height = 120,command=click).grid(row=1,column=3)#3
Button(fr2, image = img7, width = 125, height = 120, command=click).grid(row=2,column=1)#4
Button(fr2, image = img8, width = 125, height = 120,command=click).grid(row=2,column=2)#5
Button(fr2, image = img3, width = 125, height = 120, command=sel3).grid(row=2,column=3)#6
Button(fr2, image = img2, width = 125, height = 120, command=sel1).grid(row=3,column=1)#7
Button(fr2, image = img4, width = 125, height = 120,command=sel3).grid(row=3,column=2)#8
Button(fr2, image = img9, width = 125, height = 120, command=click).grid(row=3,column=3)#9

#Button(fr3, bg = 'lightblue',text = "Verify",command=check).place(x=300,y=400)
Button(fr2, bg = 'lightblue',text = "Verify",width = 17,command=check).grid(row=4,column=3)
#label.place(x=50,y=30)
    
captcha.mainloop()

# %%
from tkinter import*
from tkinter import messagebox
from PIL import Image, ImageTk

captcha = Tk()

captcha.geometry('400x525')
captcha.resizable(False, False)
captcha.title('Image Captcha')

l=[]

def WrongImage(event):
    Button1.config(image = correct)
    x=str('Incorrect image')
    l.append(x)
    
    
def WrongImage1(event):
    Button3.config(image = correct)
    x=str('Incorrect image')
    l.append(x)
    
    
def WrongImage2(event):
    Button4.config(image = correct)
    x=str('Incorrect image')
    l.append(x)
    
    
def WrongImage3(event):
    Button5.config(image = correct)
    x=str('Incorrect image')
    l.append(x)
    
    
def WrongImage4(event):
    Button9.config(image = correct)
    x=str('Incorrect image')
    l.append(x)
    
    
def Select(event):
    Button2.config(image = correct)
    x=str('Correct1')
    l.append(x)
    
    
def Select1(event):
    Button7.config(image = correct)
    x=str('correct2')
    l.append(x)
    
    
def Select2(event):
    Button6.config(image = correct)
    x=str('Correct3')
    l.append(x)
    
    
def Select3(event):
    Button8.config(image = correct)
    x=str('Correct4')
    l.append(x)
    
    
def check():
    
    if('Incorrect image' in l):
        print("captcha is incorrect")
        messagebox.showinfo("captcha","Captcha incorrect")
        l.clear()
        
    elif('Correct1' in l and 'correct2' in l and 'Correct3' in l and 'Correct4' in l ):
        print("captcha is correct")
        messagebox.showinfo("captcha","Captcha correct")
        l.clear()
        
    else:
        print('invalid captcha')
        messagebox.showinfo("captcha","Captcha incorrect")
        l.clear()
    captcha.destroy()

    
fr1 = Frame(captcha , height = 50 , width = 120)
fr1.pack(fill = 'x')
fr1.pack_propagate(False)


fr2 = Frame(captcha , height = 450)
fr2.pack(fill = 'x')
fr2.pack_propagate(False)


lg = PhotoImage(file = 'car.png')
c = Image.open('car.png')
d = c.resize((50, 50))
lg = ImageTk.PhotoImage(d)


label = Label(fr1,bg = 'white',image=lg ,height = 95, width = 50)
label.grid(row = 0,column = 1)


x = Label(fr1 , bg = 'white' , height = 5 , width = 35 , text = 'Select all the Images with Cars' , font = ('Calibri 12'))
x.grid(row = 0,column = 2)


a = Image.open('Recaptchlogo.png')
b = a.resize((50, 50))
re = ImageTk.PhotoImage(b)


captcha.wm_iconbitmap('icon.ico')


m = Label(fr1,bg = 'white',image = re,height = 95, width = 50)
m.grid(row = 0,column = 3)


image = Image.open('car4.png')
g = image.resize((125, 120))
img1 = ImageTk.PhotoImage(g)


e = Image.open('car1.png')
f = e.resize((125, 120))
img2 = ImageTk.PhotoImage(f)


h = Image.open('car2.png')
i = h.resize((125, 120))
img3 =ImageTk.PhotoImage(i)


j = Image.open('car3.png')
k = j.resize((120, 120))
img4 = ImageTk.PhotoImage(k)


n = Image.open('bike3.png')
o = n.resize((125, 120))
img5 = ImageTk.PhotoImage(o)


p = Image.open('cy1.png')
q = p.resize((125, 120))
img6 = ImageTk.PhotoImage(q)


r = Image.open('tc1.png')
s = r.resize((125, 120))
img7 = ImageTk.PhotoImage(s)


u = Image.open('lr1.png')
v = u.resize((125, 120))
img8 = ImageTk.PhotoImage(v)


w = Image.open('bike2.png')
x = w.resize((125, 120))
img9 = ImageTk.PhotoImage(x)


ab = Image.open('correct1.png')
cd = ab.resize((125, 120))
correct = ImageTk.PhotoImage(ab)


img = PhotoImage(file = 'download.png')

Button1 = Button(fr2, image = img5, width = 125, height = 120)#1

Button1.grid(row = 1,column = 1)
Button1.bind('<Button-1>', WrongImage)


Button2 = Button(fr2, image = img1, width = 125, height = 120)

Button2.grid(row = 1,column = 2)#2
Button2.bind('<Button-1>', Select)


Button3 = Button(fr2, image = img6, width = 125, height = 120)

Button3.grid(row = 1,column = 3)#3
Button3.bind('<Button-1>', WrongImage1)


b4 = Button(fr2, image = img7, width = 125, height = 120)

b4.grid(row = 2,column = 1)#4
b4.bind('<Button-1>', WrongImage2)


Button5 = Button(fr2, image = img8, width = 125, height = 120)

Button5.grid(row = 2,column = 2)#5
Button5.bind('<Button-1>', WrongImage3)


Button6 = Button(fr2, image = img3, width = 125, height = 120)

Button6.grid(row = 2,column = 3)#6
Button6.bind('<Button-1>', Select2)


Button7 = Button(fr2, image = img2, width = 125, height = 120)

Button7.grid(row = 3,column = 1)#7
Button7.bind('<Button-1>', Select1)


Button8 = Button(fr2, image = img4, width = 125, height = 120)

Button8.grid(row = 3,column = 2)#8
Button8.bind('<Button-1>', Select3)


Button9 = Button(fr2, image = img9, width = 125, height = 120)

Button9.grid(row = 3,column = 3)#9
Button9.bind('<Button-1>', WrongImage4)


Button(fr2, bg = 'lightblue',text = "Verify",width = 17,command = check).grid(row = 4,column = 3)
    
captcha.mainloop()

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk
